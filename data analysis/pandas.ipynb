# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### What you need to learn
# - loading data ✅
# - selection
#     - cols ✅
#     - rows ✅
# - manipulation
#     - add column ✅
#     - remove columns ✅
#     - rename columns ✅
#     - change data type
#     - delete data
#     - remove duplicates
#     - sort
#     - group
#     - pivot
#     - merge
# - visualization
#     - line plot
#     - bar plot
#     - histogram
#     - box plot
#     - scatter plot
#     - pie chart
#     - heatmap
#     - word cloud

# %%
penguins = sns.load_dataset('penguins')
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %% [markdown]
# - analysis
#     - univariate analysis
#     - bi-variate analysis
#     - multi-variate analysis

# %% [markdown]
# - loading data
#     - custom data from a variable
#     - excel data
#     - csv/ json/ etc
#     - database (sql)

# %%
students = {
    'name':['Vaibhav', 'Siya', 'Aman','Amjad', 'Sneha','Aditi','Bhupendra'],
    'college':['SRMCEM', 'SRMCEM', "KMC", "KMC", 'CU','SRMCEM','SRMCEM'],
    'dob':['25 Jan','2 Feb','2 Apr', '16 Aug', '16 Sep','17 Dec','22 May']
}
sdf = pd.DataFrame(students)
print(type(sdf))
sdf
# Out:
# <class 'pandas.DataFrame'>
#         name college     dob
# 0    Vaibhav  SRMCEM  25 Jan
# 1       Siya  SRMCEM   2 Feb
# 2       Aman     KMC   2 Apr
# 3      Amjad     KMC  16 Aug
# 4      Sneha      CU  16 Sep
# 5      Aditi  SRMCEM  17 Dec
# 6  Bhupendra  SRMCEM  22 May

# %%
data = pd.read_excel(r'C:\Users\hamen\Downloads\ds\data analysis\bahut_kharab_data.xlsx')
data
# Out:
#    sno            Names  Age    Pincode
# 0    1       Ajay KumaR   45     202100
# 1    2       RAju Singh   34   230510al
# 2    3  VIKAS narayan ?   12     123311
# 3    4     Smarth Singh  NaN     293199
# 4    5      Vijay NiGAM   12  asd899212
# 5    6    Suresh PANDEY  A12        NaN
# 6    7    VIMLESH kumar  32?     343234
# 7    8      Sunil Singh  NaN        NaN
# 8    9         Amir ali   56        NaN
# 9   10    Vimal KuMar..   56        NaN

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   sno      10 non-null     int64
#  1   Names    10 non-null     str
#  2   Age      8 non-null      object
#  3   Pincode  6 non-null      object
# dtypes: int64(1), object(2), str(1)
# memory usage: 452.0+ bytes

# %%
data.columns.tolist()
# Out:
# ['sno', 'Names', 'Age', 'Pincode']

# %%
data[['Names','Age']]
# Out:
#              Names  Age
# 0       Ajay KumaR   45
# 1       RAju Singh   34
# 2  VIKAS narayan ?   12
# 3     Smarth Singh  NaN
# 4      Vijay NiGAM   12
# 5    Suresh PANDEY  A12
# 6    VIMLESH kumar  32?
# 7      Sunil Singh  NaN
# 8         Amir ali   56
# 9    Vimal KuMar..   56

# %%
data.Age # column selection as object attribute
# Out:
# 0     45
# 1     34
# 2     12
# 3    NaN
# 4     12
# 5    A12
# 6    32?
# 7    NaN
# 8     56
# 9     56
# Name: Age, dtype: object

# %%
# data[collist]
data[['Names','Age']] # column selection as list of columns
# Out:
#              Names  Age
# 0       Ajay KumaR   45
# 1       RAju Singh   34
# 2  VIKAS narayan ?   12
# 3     Smarth Singh  NaN
# 4      Vijay NiGAM   12
# 5    Suresh PANDEY  A12
# 6    VIMLESH kumar  32?
# 7      Sunil Singh  NaN
# 8         Amir ali   56
# 9    Vimal KuMar..   56

# %% [markdown]
# operations between columns (numeric)

# %%
data['amt'] * data['qty']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\ops\array_ops.py:220, in _na_arithmetic_op(left, right, op, is_cmp)
#     219 try:
# --> 220     result = func(left, right)
#     221 except TypeError:
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\computation\expressions.py:243, in evaluate(op, left_op, right_op, use_numexpr)
#     241     if use_numexpr:
#     242         # error: "None" not callable
# --> 243         return _evaluate(op, op_str, left_op, right_op)  # type: ignore[misc]
#     244 return _evaluate_standard(op, op_str, left_op, right_op)
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\computation\expressions.py:74, in _evaluate_standard(op, op_str, left_op, right_op)
#      73     _store_test_result(False)
# ---> 74 return op(left_op, right_op)
#
# TypeError: can't multiply sequence by non-int of type 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 data['Age'] * data['Age']
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\ops\common.py:85, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      82     other = sanitize_array(other, None)
#      83     other = ensure_wrapped_if_datetimelike(other)
# ---> 85 return method(self, other)
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\arraylike.py:206, in OpsMixin.__mul__(self, other)
#     204 @unpack_zerodim_and_defer("__mul__")
#     205 def __mul__(self, other):
# --> 206     return self._arith_method(other, operator.mul)
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\series.py:6751, in Series._arith_method(self, other, op)
#    6749 def _arith_method(self, other, op):
#    6750     self, other = self._align_for_op(other)
# -> 6751     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\base.py:1644, in IndexOpsMixin._arith_method(self, other, op)
#    1641     rvalues = np.arange(rvalues.start, rvalues.stop, rvalues.step)
#    1643 with np.errstate(all="ignore"):
# -> 1644     result = ops.arithmetic_op(lvalues, rvalues, op)
#    1646 return self._construct_result(result, name=res_name, other=other)
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\ops\array_ops.py:289, in arithmetic_op(left, right, op)
#     285     _bool_arith_check(op, left, right)  # type: ignore[arg-type]
#     287     # error: Argument 1 to "_na_arithmetic_op" has incompatible type
#     288     # "Union[ExtensionArray, ndarray[Any, Any]]"; expected "ndarray[Any, Any]"
# --> 289     res_values = _na_arithmetic_op(left, right, op)  # type: ignore[arg-type]
#     291 return res_values
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\ops\array_ops.py:229, in _na_arithmetic_op(left, right, op, is_cmp)
#     221 except TypeError:
#     222     if not is_cmp and (
#     223         left.dtype == object or getattr(right, "dtype", None) == object
#     224     ):
#    (...)    227         # Don't do this for comparisons, as that will handle complex numbers
#     228         #  incorrectly, see GH#32047
# --> 229         result = _masked_arith_op(left, right, op)
#     230     else:
#     231         raise
#
# File c:\Users\hamen\.pyenv\pyenv-win\versions\3.11.9\Lib\site-packages\pandas\core\ops\array_ops.py:165, in _masked_arith_op(x, y, op)
#     163     # See GH#5284, GH#5035, GH#19448 for historical reference
#     164     if mask.any():
# --> 165         result[mask] = op(xrav[mask], yrav[mask])
#     167 else:
#     168     if not is_scalar(y):
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %% [markdown]
# adding columns

# %%
# data['new_col'] = expression
data['total'] = data['amt'] * data['qty']
data

# %%
data['crap'] = "some crap"
data
# Out:
#    sno          Names  Age    Pincode       crap
# 0    1     Ajay KumaR   45     202100  some crap
# 1    2     RAju Singh   34   230510al  some crap
# 2    3          Vikas   12     123311  some crap
# 3    4   Smarth Singh  NaN     293199  some crap
# 4    5    Vijay NiGAM   12  asd899212  some crap
# 5    6  Suresh PANDEY  A12        NaN  some crap
# 6    7  VIMLESH kumar  32?     343234  some crap
# 7    8    Sunil Singh  NaN        NaN  some crap
# 8    9       Amir ali   56        NaN  some crap
# 9   10  Vimal KuMar..   56        NaN  some crap

# %%
data.loc[2, 'Names'] = 'Vikas'
data
# Out:
#    sno          Names  Age    Pincode       crap
# 0    1     Ajay KumaR   45     202100  some crap
# 1    2     RAju Singh   34   230510al  some crap
# 2    3          Vikas   12     123311  some crap
# 3    4   Smarth Singh  NaN     293199  some crap
# 4    5    Vijay NiGAM   12  asd899212  some crap
# 5    6  Suresh PANDEY  A12        NaN  some crap
# 6    7  VIMLESH kumar  32?     343234  some crap
# 7    8    Sunil Singh  NaN        NaN  some crap
# 8    9       Amir ali   56        NaN  some crap
# 9   10  Vimal KuMar..   56        NaN  some crap

# %% [markdown]
# removing columns

# %%
data.drop(columns=['crap'], inplace=True) # inplace=True to make changes permanent in dataframe

# %%
data
# Out:
#    sno          Names  Age    Pincode
# 0    1     Ajay KumaR   45     202100
# 1    2     RAju Singh   34   230510al
# 2    3          Vikas   12     123311
# 3    4   Smarth Singh  NaN     293199
# 4    5    Vijay NiGAM   12  asd899212
# 5    6  Suresh PANDEY  A12        NaN
# 6    7  VIMLESH kumar  32?     343234
# 7    8    Sunil Singh  NaN        NaN
# 8    9       Amir ali   56        NaN
# 9   10  Vimal KuMar..   56        NaN

# %%
data.iloc[2]
# Out:
# sno             3
# Names       Vikas
# Age            12
# Pincode    123311
# Name: 2, dtype: object

# %%
data.iloc[:2] # first two rows
# Out:
#    sno       Names Age   Pincode
# 0    1  Ajay KumaR  45    202100
# 1    2  RAju Singh  34  230510al

# %%
data.drop(index=[2])
# Out:
#    sno          Names  Age    Pincode
# 0    1     Ajay KumaR   45     202100
# 1    2     RAju Singh   34   230510al
# 3    4   Smarth Singh  NaN     293199
# 4    5    Vijay NiGAM   12  asd899212
# 5    6  Suresh PANDEY  A12        NaN
# 6    7  VIMLESH kumar  32?     343234
# 7    8    Sunil Singh  NaN        NaN
# 8    9       Amir ali   56        NaN
# 9   10  Vimal KuMar..   56        NaN

# %%
data
# Out:
#    sno          Names  Age    Pincode
# 0    1     Ajay KumaR   45     202100
# 1    2     RAju Singh   34   230510al
# 2    3          Vikas   12     123311
# 3    4   Smarth Singh  NaN     293199
# 4    5    Vijay NiGAM   12  asd899212
# 5    6  Suresh PANDEY  A12        NaN
# 6    7  VIMLESH kumar  32?     343234
# 7    8    Sunil Singh  NaN        NaN
# 8    9       Amir ali   56        NaN
# 9   10  Vimal KuMar..   56        NaN

# %%
sdf
# Out:
#         name college     dob
# 0    Vaibhav  SRMCEM  25 Jan
# 1       Siya  SRMCEM   2 Feb
# 2       Aman     KMC   2 Apr
# 3      Amjad     KMC  16 Aug
# 4      Sneha      CU  16 Sep
# 5      Aditi  SRMCEM  17 Dec
# 6  Bhupendra  SRMCEM  22 May

# %%
data['sno'] = data['sno'] - 10

# %%
data
# Out:
#    sno          Names  Age    Pincode
# 0   -9     Ajay KumaR   45     202100
# 1   -8     RAju Singh   34   230510al
# 2   -7          Vikas   12     123311
# 3   -6   Smarth Singh  NaN     293199
# 4   -5    Vijay NiGAM   12  asd899212
# 5   -4  Suresh PANDEY  A12        NaN
# 6   -3  VIMLESH kumar  32?     343234
# 7   -2    Sunil Singh  NaN        NaN
# 8   -1       Amir ali   56        NaN
# 9    0  Vimal KuMar..   56        NaN

# %%
data.columns.tolist()

# %%
data.rename(
    mapper={'Item': 'product',
            'qty': 'quantity',
            'amt': 'Price',
            'total': 'Expenditure'},
    axis=1,
    inplace=True
)
data

# %% [markdown]
# 23-oct-23
#
# Operations
# - delete data (drop)
#     - columns
#     - indexes
# - remove duplicates
# - sort
# - group
# - pivot
# - merge

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
penguins.columns.tolist()
# Out:
# ['species',
#  'island',
#  'bill_length_mm',
#  'bill_depth_mm',
#  'flipper_length_mm',
#  'body_mass_g',
#  'sex']

# %%
penguins.drop(columns='body_mass_g')
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#         sex
# 0      Male
# 1    Female
# 2    Female
# 3       NaN
# 4    Female
# ..      ...
# 339     NaN
# 340  Female
# 341    Male
# 342  Female
# 343    Male
#
# [344 rows x 6 columns]

# %%
penguins.drop(columns=['island','body_mass_g'])
# Out:
#     species  bill_length_mm  bill_depth_mm  flipper_length_mm     sex
# 0    Adelie            39.1           18.7              181.0    Male
# 1    Adelie            39.5           17.4              186.0  Female
# 2    Adelie            40.3           18.0              195.0  Female
# 3    Adelie             NaN            NaN                NaN     NaN
# 4    Adelie            36.7           19.3              193.0  Female
# ..      ...             ...            ...                ...     ...
# 339  Gentoo             NaN            NaN                NaN     NaN
# 340  Gentoo            46.8           14.3              215.0  Female
# 341  Gentoo            50.4           15.7              222.0    Male
# 342  Gentoo            45.2           14.8              212.0  Female
# 343  Gentoo            49.9           16.1              213.0    Male
#
# [344 rows x 5 columns]

# %%
penguins.drop(index=2) # drop row 3rd
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [343 rows x 7 columns]

# %%
penguins.drop(index=[0,1,2,3,4]) # drop multiple rows

# %%
penguins.drop(index=range(10)) # drop multiple rows using range

# %%
np.nan
# Out:
# nan

# %% [markdown]
# find the missing number of values in each columns

# %%
penguins.isnull().sum()
# Out:
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# dtype: int64

# %%
sns.heatmap(penguins.isnull(), cbar=False) # overall null value visualization
# Out:
# <Axes: >

# %%
penguins.isnull().sum().plot(kind='bar') # column wise null value visualization
# Out:
# <Axes: >

# %% [markdown]
# removing missing values (nan values)

# %%
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 3            NaN     NaN
# 4         3450.0  Female
# ..           ...     ...
# 339          NaN     NaN
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [344 rows x 7 columns]

# %%
penguins.dropna() # drop rows with null values
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 338  Gentoo     Biscoe            47.2           13.7              214.0
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 338       4925.0  Female
# 340       4850.0  Female
# 341       5750.0    Male
# 342       5200.0  Female
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
penguins.shape
# Out:
# (344, 7)

# %%
penguins.dropna().shape
# Out:
# (333, 7)

# %%
penguins.dropna(inplace=True)
print(penguins.shape)
# Out:
# (333, 7)

# %%
penguins.drop_duplicates(subset=['bill_length_mm']) # example
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 4    Adelie  Torgersen            36.7           19.3              193.0
# 5    Adelie  Torgersen            39.3           20.6              190.0
# ..      ...        ...             ...            ...                ...
# 326  Gentoo     Biscoe            41.7           14.7              210.0
# 327  Gentoo     Biscoe            53.4           15.8              219.0
# 335  Gentoo     Biscoe            55.1           16.0              230.0
# 337  Gentoo     Biscoe            48.8           16.2              222.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# 2         3250.0  Female
# 4         3450.0  Female
# 5         3650.0    Male
# ..           ...     ...
# 326       4700.0  Female
# 327       5500.0    Male
# 335       5850.0    Male
# 337       6000.0    Male
# 343       5400.0    Male
#
# [163 rows x 7 columns]

# %%
penguins.sort_values(by='sex',ascending=True) # sort
# Out:
#        species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 172  Chinstrap   Dream            42.4           17.3              181.0
# 136     Adelie   Dream            35.6           17.5              191.0
# 138     Adelie   Dream            37.0           16.5              185.0
# 272     Gentoo  Biscoe            45.1           14.4              210.0
# 140     Adelie   Dream            40.2           17.1              193.0
# ..         ...     ...             ...            ...                ...
# 163  Chinstrap   Dream            51.7           20.3              194.0
# 165  Chinstrap   Dream            52.0           18.1              201.0
# 167  Chinstrap   Dream            50.5           19.6              201.0
# 145     Adelie   Dream            39.0           18.7              185.0
# 343     Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 172       3600.0  Female
# 136       3175.0  Female
# 138       3400.0  Female
# 272       4400.0  Female
# 140       3400.0  Female
# ..           ...     ...
# 163       3775.0    Male
# 165       4050.0    Male
# 167       4050.0    Male
# 145       3650.0    Male
# 343       5400.0    Male
#
# [333 rows x 7 columns]

# %%
penguins.sort_values(by=['sex','island'])
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 20   Adelie     Biscoe            37.8           18.3              174.0
# 22   Adelie     Biscoe            35.9           19.2              189.0
# 25   Adelie     Biscoe            35.3           18.9              187.0
# 27   Adelie     Biscoe            40.5           17.9              187.0
# 28   Adelie     Biscoe            37.9           18.6              172.0
# ..      ...        ...             ...            ...                ...
# 123  Adelie  Torgersen            41.4           18.5              202.0
# 125  Adelie  Torgersen            40.6           19.0              199.0
# 127  Adelie  Torgersen            41.5           18.3              195.0
# 129  Adelie  Torgersen            44.1           18.0              210.0
# 131  Adelie  Torgersen            43.1           19.2              197.0
#
#      body_mass_g     sex
# 20        3400.0  Female
# 22        3800.0  Female
# 25        3800.0  Female
# 27        3200.0  Female
# 28        3150.0  Female
# ..           ...     ...
# 123       3875.0    Male
# 125       4000.0    Male
# 127       4300.0    Male
# 129       4000.0    Male
# 131       3500.0    Male
#
# [333 rows x 7 columns]

# %% [markdown]
# datatypes in pandas
# - int
# - float
# - boolean
# - datetime
# - object (if datatype is not understood by pandas then object is used)
# - string (not understood by pandas by default, unless you specify)
# - category

# %%
penguins.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 333 entries, 0 to 343
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   species            333 non-null    str
#  1   island             333 non-null    str
#  2   bill_length_mm     333 non-null    float64
#  3   bill_depth_mm      333 non-null    float64
#  4   flipper_length_mm  333 non-null    float64
#  5   body_mass_g        333 non-null    float64
#  6   sex                333 non-null    str
# dtypes: float64(4), str(3)
# memory usage: 20.8 KB

# %%
penguins.dtypes # data types of columns
# Out:
# species                  str
# island                   str
# bill_length_mm       float64
# bill_depth_mm        float64
# flipper_length_mm    float64
# body_mass_g          float64
# sex                      str
# dtype: object

# %%
penguins.select_dtypes(include='number') # select only object type columns
# Out:
#      bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# 0              39.1           18.7              181.0       3750.0
# 1              39.5           17.4              186.0       3800.0
# 2              40.3           18.0              195.0       3250.0
# 4              36.7           19.3              193.0       3450.0
# 5              39.3           20.6              190.0       3650.0
# ..              ...            ...                ...          ...
# 338            47.2           13.7              214.0       4925.0
# 340            46.8           14.3              215.0       4850.0
# 341            50.4           15.7              222.0       5750.0
# 342            45.2           14.8              212.0       5200.0
# 343            49.9           16.1              213.0       5400.0
#
# [333 rows x 4 columns]

# %%
penguins.select_dtypes(include='object')
# Out:
# C:\Users\hamen\AppData\Local\Temp\ipykernel_32160\651218887.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   penguins.select_dtypes(include='object')
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %%
penguins.select_dtypes(exclude='number') # select all columns except numeric
# Out:
#     species     island     sex
# 0    Adelie  Torgersen    Male
# 1    Adelie  Torgersen  Female
# 2    Adelie  Torgersen  Female
# 4    Adelie  Torgersen  Female
# 5    Adelie  Torgersen    Male
# ..      ...        ...     ...
# 338  Gentoo     Biscoe  Female
# 340  Gentoo     Biscoe  Female
# 341  Gentoo     Biscoe    Male
# 342  Gentoo     Biscoe  Female
# 343  Gentoo     Biscoe    Male
#
# [333 rows x 3 columns]

# %% [markdown]
# change the datatype of a column

# %%
penguins['island'].astype('category') # not actually applied on the column
# Out:
# 0      Torgersen
# 1      Torgersen
# 2      Torgersen
# 4      Torgersen
# 5      Torgersen
#          ...
# 338       Biscoe
# 340       Biscoe
# 341       Biscoe
# 342       Biscoe
# 343       Biscoe
# Name: island, Length: 333, dtype: category
# Categories (3, str): ['Biscoe', 'Dream', 'Torgersen']

# %%
penguins['island'] = penguins['island'].astype('category') # casting object to category

# %%
penguins.dtypes
# Out:
# species                   str
# island               category
# bill_length_mm        float64
# bill_depth_mm         float64
# flipper_length_mm     float64
# body_mass_g           float64
# sex                       str
# dtype: object

# %%
penguins.sex = penguins.sex.astype('bool')
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g   sex
# 0       3750.0  True
# 1       3800.0  True
# 2       3250.0  True
# 4       3450.0  True
# 5       3650.0  True

# %% [markdown]
# simple visualization - univariate
# - for numerical data
#     - line plot -> `.plot()`
#     - bar plot -> `.plot(kind='bar')`
#     - box plot -> `.plot(kind='box')`
#     - area plot -> `.plot(kind='area')`
#     - histogram -> `.hist()`
# - for categorical data
#     - bar plot -> `.plot(kind='bar')`
#     - pie chart -> `.plot(kind='pie')`

# %%
penguins['bill_depth_mm'].hist()
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='area', figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins['bill_depth_mm'].plot(kind='box', figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex'],
#       dtype='str')

# %%
penguins['bill_depth_mm'].plot(kind='box', figsize=(5,3), vert=False)
# Out:
# <Axes: >

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       163
# Dream        123
# Torgersen     47
# Name: count, dtype: int64

# %%
penguins['island'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='island'>

# %% [markdown]
# comparing univariate data in a single graph

# %%
penguins[['bill_depth_mm','bill_length_mm']]

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot()
# Out:
# <Axes: >

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(kind='box', figsize=(15,5))
# Out:
# <Axes: >

# %%
penguins[['bill_depth_mm','bill_length_mm']].hist(bins=20, figsize=(10,5))
# Out:
# array([[<Axes: title={'center': 'bill_depth_mm'}>,
#         <Axes: title={'center': 'bill_length_mm'}>]], dtype=object)

# %% [markdown]
# putting columns visualization in subplots

# %%
penguins[['bill_depth_mm','bill_length_mm']].plot(layout=(1, 2),
                                                  subplots=True,
                                                  figsize=(15,5))
# Out:
# array([[<Axes: >, <Axes: >]], dtype=object)

# %% [markdown]
# the power of seaborn - better visualization

# %%
sns.displot(data=penguins, x='bill_depth_mm')

# %%
sns.displot(data=penguins, x='body_mass_g', hue='island')

# %%
sns.countplot(data=penguins, x='island')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %%
sns.countplot(data=penguins, x='island', hue='species')
# Out:
# <Axes: xlabel='island', ylabel='count'>

# %% [markdown]
# bivariate analysis
# - scatter plot (numeric vs numeric)
# - violin plot (alternative to box plot)
# - pair plot

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='species')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', y='bill_depth_mm', hue='island')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
sns.color_palette('RdBu')
# Out:
# [(0.7561707035755478, 0.21038062283737025, 0.22352941176470587),
#  (0.940715109573241, 0.6099192618223759, 0.4812764321414839),
#  (0.9856978085351787, 0.8889657823913879, 0.8320645905420992),
#  (0.8605151864667436, 0.9174163783160324, 0.9487120338331411),
#  (0.530026912725875, 0.7456362937331797, 0.8560553633217994),
#  (0.1843137254901961, 0.47266435986159167, 0.7116493656286044)]

# %%
sns.set_palette('rainbow_r')

# %%
sns.scatterplot(data=penguins, x='bill_length_mm', 
                y='bill_depth_mm', hue='island', palette='coolwarm')
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>
